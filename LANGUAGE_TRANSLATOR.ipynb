# %%
# !pip install deep-translator gTTS

from deep_translator import GoogleTranslator
from gtts import gTTS
from IPython.display import Audio, display

while True:

    text = input("Enter text (type exit to stop): ").strip()

    if text.lower() == "exit":
        print("Exiting Translator. Goodbye!")
        break

    if text == "":
        print("⚠️ Please enter some text to translate.\n")
        continue

    source = input("Source language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): ").strip().lower()
    target = input("Target language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): ").strip().lower()

    try:
        translated = GoogleTranslator(source=source, target=target).translate(text)

        print("\nTranslated Text:")
        print(translated)

        # Bonus: Text-to-Speech output
        speak = input("\nDo you want to hear the translation? (y/n): ").strip().lower()
        if speak == "y":
            try:
                tts = gTTS(text=translated, lang=target)
                tts.save("translated_audio.mp3")
                display(Audio("translated_audio.mp3", autoplay=True))
            except Exception as e:
                print(f"⚠️ Could not generate audio for this language: {e}")

        print("\n" + "-"*40 + "\n")

    except Exception as e:
        print(f"⚠️ Translation failed. Please check your language codes.\nError: {e}\n")
# Out:
# Requirement already satisfied: deep-translator in /usr/local/lib/python3.12/dist-packages (1.11.4)
# Requirement already satisfied: gTTS in /usr/local/lib/python3.12/dist-packages (2.5.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.12/dist-packages (from deep-translator) (4.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from deep-translator) (2.32.4)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.12/dist-packages (from gTTS) (8.1.8)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2026.6.17)
# Enter text (type exit to stop): what are u doing ?
# Source language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): en
# Target language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): ar
#
# Translated Text:
# ماذا تفعل ؟
#
# Do you want to hear the translation? (y/n): y
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ----------------------------------------
#
# Enter text (type exit to stop): pakistani people are very hospitable
# Source language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): en
# Target language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): ur
#
# Translated Text:
# پاکستانی لوگ بہت مہمان نواز ہیں۔
#
# Do you want to hear the translation? (y/n): y
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ----------------------------------------
#
# Enter text (type exit to stop): how r u
# Source language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): en
# Target language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): ar
#
# Translated Text:
# كيف حالك
#
# Do you want to hear the translation? (y/n): y
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ----------------------------------------
#
# Enter text (type exit to stop): i m a photographer
# Source language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): en
# Target language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): ur
#
# Translated Text:
# میں ایک فوٹوگرافر ہوں۔
#
# Do you want to hear the translation? (y/n): y
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ----------------------------------------
#
# Enter text (type exit to stop): exit
# Exiting Translator. Goodbye!

# %%
# !pip install deep-translator gTTS

from deep_translator import GoogleTranslator
from gtts import gTTS
from IPython.display import Audio, display

while True:

    text = input("Enter text (type exit to stop): ").strip()

    if text.lower() == "exit":
        print("Exiting Translator. Goodbye!")
        break

    if text == "":
        print("⚠️ Please enter some text to translate.\n")
        continue

    source = input("Source language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): ").strip().lower()
    target = input("Target language code (e.g. en, ur, fr, ar, es, de, hi, zh-CN): ").strip().lower()

    try:
        translated = GoogleTranslator(source=source, target=target).translate(text)

        print("\nTranslated Text:")
        print(translated)

        # Bonus: Text-to-Speech output
        speak = input("\nDo you want to hear the translation? (y/n): ").strip().lower()
        if speak == "y":
            try:
                tts = gTTS(text=translated, lang=target)
                tts.save("translated_audio.mp3")
                display(Audio("translated_audio.mp3", autoplay=True))
            except Exception as e:
                print(f"⚠️ Could not generate audio for this language: {e}")

        print("\n" + "-"*40 + "\n")

    except Exception as e:
        print(f"⚠️ Translation failed. Please check your language codes.\nError: {e}\n")
# Out:
# Requirement already satisfied: deep-translator in /usr/local/lib/python3.12/dist-packages (1.11.4)
# Requirement already satisfied: gTTS in /usr/local/lib/python3.12/dist-packages (2.5.4)
# Requirement already satisfied: beautifulsoup4<5.0.0,>=4.9.1 in /usr/local/lib/python3.12/dist-packages (from deep-translator) (4.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from deep-translator) (2.32.4)
# Requirement already satisfied: click<8.2,>=7.1 in /usr/local/lib/python3.12/dist-packages (from gTTS) (8.1.8)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (2.8.4)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4<5.0.0,>=4.9.1->deep-translator) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.23.0->deep-translator) (2026.6.17)
#
# Translated Text:
# آپ کا نام کیا ہے
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ----------------------------------------
#
#
# Translated Text:
# طیبہ کہاں ہے؟
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ----------------------------------------
#
#
# Translated Text:
# آج کل AI پوری دنیا میں بہت مشہور ہو چکا ہے۔
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# ----------------------------------------
